# %% [markdown]
# Importando a biblioteca pandas para realizar o tratamento de dados.

# %%
import pandas as pd

# %% [markdown]
# Aplicação de Funções para Tratamento de Dados

# %%
## Usando uma função para limpar o texto (Padronizando ele em minúsculo)
def limpar_texto(df, coluna):
    df[coluna] = df[coluna].str.strip().str.lower()
    return df

    
## Usando uma função para remover duplicatas
def remover_duplicata(df, subset_colunas = None):
    #Contar quantas linhas existem antes
    linhas_antes = df.shape[0]
    
    #Aplicar a remoção
    df_limpo = df.drop_duplicates(subset=subset_colunas)
    
    #Contar quantas linhas sobraram
    linhas_depois = df_limpo.shape[0]
    
    #Calcular a diferença
    total_duplicadas = linhas_antes - linhas_depois
    
    #Exibir a mensagem 
    if total_duplicadas > 0:
        print(f"Foram encontradas e removidas {total_duplicadas} duplicatas.")
    else:
        print("Não existem duplicatas nesta base.")
        
    return df_limpo


    ## usando uma função para converter para datatime
def converter_para_data(df, colunas):
    for coluna in colunas:
        df[coluna] = pd.to_datetime(df[coluna])
    return df

# %% [markdown]
# Importação e Tratamento da Base de Dados

# %%
# # ## Importando a base de dados : olist_customers_dataset
df_customers = pd.read_csv('olist_customers_dataset.csv')

# ## Fazendo uma copia da base original
df_customers_limpo = df_customers.copy()
print(df_customers_limpo)
## Verificando se existe valores nulos da base:olist_customers_dataset
print (df_customers.isnull().sum())

## Removendo espaço e padronizando os textos da base : olist_customers_dataset usando a função Limpar texto
df_customers_limpo = limpar_texto(df_customers_limpo, 'customer_city')
print(df_customers_limpo)

# # Removendo duplicatas
df_customers_limpo = remover_duplicata(df_customers_limpo,['customer_id', 'customer_unique_id', 'customer_zip_code_prefix']  )
print(df_customers_limpo)

## Exportando a base de dados

df_customers_limpo.to_csv('df_customers_limpo.csv', index=False, encoding='utf-8')

# %%
## Importanto a base de dados :olist_geolocation_dataset
df_geolocation = pd.read_csv('olist_geolocation_dataset.csv')

# ## Criando uma copia da base original
df_geolocation_limpo = df_geolocation.copy()

print(df_geolocation_limpo)

# ## Verificando se existe valores nulos da base:olist_geolocation_dataset
print (df_geolocation_limpo.isnull().sum())

## Removendo espaço e padronizando os textos da base : olist_geolocation_dataset usando a função Limpar texto
df_geolocation_limpo = limpar_texto(df_geolocation_limpo, 'geolocation_city')
print(df_geolocation_limpo)

## Exportando a base de dados
df_geolocation_limpo.to_csv('df_geolocation_limpo.csv', index=False, encoding='utf-8')

# %%
##Importanto a base de dados :olist_order_items_dataset
df_order_items = pd.read_csv('olist_order_items_dataset.csv')


##Criando uma copia da base original
df_order_items_limpo = df_order_items.copy()

## Verificando se existe valores nulos da base:order_items
print (df_order_items_limpo.isnull().sum())

## Removendo duplicatas
df_order_items_limpo = remover_duplicata(df_order_items_limpo,['order_id', 'product_id', 'seller_id']  )
print( df_order_items_limpo)

##Convertendo data
# Substitua a sua linha por esta:
df_order_items_limpo['shipping_limit_date'] = pd.to_datetime(df_order_items_limpo['shipping_limit_date'])

# Exportando a base de dados
df_order_items_limpo.to_csv('df_order_items_limpo.csv', index=False, encoding='utf-8')

# %%
## Importanto a base de dados :olist_order_payments_dataset
df_olist_order_payments= pd.read_csv('olist_order_payments_dataset.csv')

# ## Criando uma copia da base original
df_olist_order_payments_limpo = df_olist_order_payments.copy()

## Verificando se existe valores nulos da base:order_items
print (df_olist_order_payments_limpo.isnull().sum())

## Removendo espaço e padronizando os textos da base : df_olist_order_payments_limpo  usando a função Limpar texto
df_olist_order_payments_limpo = limpar_texto(df_olist_order_payments_limpo, 'payment_type')
print(df_olist_order_payments_limpo)

##Removendo duplicatas
df_olist_order_payments_limpo = remover_duplicata(df_olist_order_payments_limpo,'order_id'  )
print( df_olist_order_payments_limpo)

## Exportando a base de dados
df_olist_order_payments_limpo.to_csv('df_olist_order_payments_limpo.csv', index=False, encoding='utf-8')

# %%
## Importanto a base de dados :olist_order_reviews_dataset
df_olist_order_reviews = pd.read_csv('olist_order_reviews_dataset.csv', encoding='utf-8')

## Criando uma copia da base original
df_olist_order_reviews_limpo = df_olist_order_reviews.copy()

print(df_olist_order_reviews_limpo)

##Verificando se existe valores nulos na base ; olist_order_reviews_limpo
print (df_olist_order_reviews_limpo.isnull().sum())

## Preenchendo valores nulos nos comentários e títulos
df_olist_order_reviews_limpo['review_comment_message'] = df_olist_order_reviews_limpo['review_comment_message'].fillna('Sem mensagem')
df_olist_order_reviews_limpo['review_comment_title'] = df_olist_order_reviews_limpo['review_comment_title'].fillna('Sem título')

## Verificando novamente se ainda existem nulos
print(df_olist_order_reviews_limpo.isnull().sum())

## Removendo duplicatas
df_olist_order_reviews_limpo = remover_duplicata(df_olist_order_reviews_limpo,['review_id','order_id'])

## Convertendo data
df_olist_order_reviews_limpo = converter_para_data(df_olist_order_reviews_limpo,['review_creation_date','review_answer_timestamp'])

## Exportando a base de dados
df_olist_order_reviews_limpo.to_csv('df_olist_order_reviews_limpo.csv', index=False, encoding='utf-8')

# %%
## Importanto a base de dados :olist_orders_dataset
df_olist_orders_dataset = pd.read_csv('olist_orders_dataset.csv')

## Criando uma copia da base original
df_olist_orders_dataset_limpo = df_olist_orders_dataset.copy()

##Verificando se existe valores nulos na base: olist_orders_dataset
print(df_olist_orders_dataset_limpo.isnull().sum())

## Convertendo data
df_olist_orders_dataset_limpo = converter_para_data(df_olist_orders_dataset_limpo,['order_purchase_timestamp','order_approved_at','order_delivered_carrier_date','order_delivered_customer_date','order_estimated_delivery_date'])

## Exportando a base de dados
df_olist_orders_dataset_limpo.to_csv('df_olist_orders_dataset_limpo.csv', index=False, encoding='utf-8')

# %%
## Importando a base de dados :olist_products_dataset
df_olist_products_dataset = pd.read_csv('olist_products_dataset.csv')

## Criando uma copia da base original
df_olist_products_dataset_limpo = df_olist_products_dataset.copy()

## Verificando se existe valores nulos na base
print(df_olist_products_dataset_limpo.isnull().sum())



## Preenchendo os valores nulos do tipo string
df_olist_products_dataset_limpo['product_category_name'] = df_olist_products_dataset_limpo['product_category_name'].fillna('Nao Informado')

# Preenchendo os valores nulos do tipo númericos 
colunas = ['product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm' , 'product_name_lenght','product_description_lenght','product_photos_qty']
df_olist_products_dataset_limpo[colunas] = df_olist_products_dataset_limpo[colunas].fillna(0)

## Verificando se ainda existe valores nulos
print(df_olist_products_dataset_limpo.isnull().sum())

## Verificando e removendo as duplicatas
df_olist_products_dataset_limpo = remover_duplicata(df_olist_products_dataset_limpo,['product_id'])


## Removendo espaço e padronizando os textos da base usando a função Limpar texto
df_olist_products_dataset_limpo = limpar_texto(df_olist_products_dataset_limpo, 'product_category_name')
print(df_olist_products_dataset_limpo)

## Exportando a base de dados
df_olist_products_dataset_limpo.to_csv('df_olist_products_dataset_limpo.csv', index=False, encoding='utf-8')

# %%
## Importando a base de dados : olist_sellers_dataset
df_olist_sellers_dataset = pd.read_csv('olist_sellers_dataset.csv')

## Criando uma copia da base original 
df_olist_sellers_dataset_limpo = df_olist_sellers_dataset.copy()

## Verificando se existe valores nulos
print(df_olist_sellers_dataset_limpo .isnull().sum())

## Verificando e removendo as duplicatas
df_olist_sellers_dataset_limpo  = remover_duplicata(df_olist_sellers_dataset_limpo ,['seller_id'])

## Exportando a base de dados
df_olist_sellers_dataset_limpo.to_csv('df_olist_sellers_dataset_limpo.csv', index=False, encoding='utf-8')

# %%
#Importanto a base de dados : product_category_name_translation

df_product_category_name_translation= pd.read_csv('product_category_name_translation.csv')

## Criando uma copia da base original 
product_category_name_translation_limpo = df_product_category_name_translation.copy()

## Verificando se existe valores nulos
print(product_category_name_translation_limpo .isnull().sum())
## Exportando a base de dados
product_category_name_translation_limpo.to_csv('product_category_name_translation_limpo.csv', index=False, encoding='utf-8')
